# %% [markdown]
# # Julia Playground
# Quickly going through the tutorials found at https://github.com/JuliaComputing/JuliaBoxTutorials/tree/master/introductory-tutorials/intro-to-julia/short-version

# %% [markdown]
# ## Introduction

# %%
3+7
# Out:
# 10

# %%
println("Hello World")
# Out:
# Hello World

# %%
?println
# Out:
# search: println printstyled print sprint isprint
#   println([io::IO], xs...)
#
#   Print (using print) xs followed by a newline. If io is not supplied, prints
#   to stdout.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   julia> println("Hello, world")
#   Hello, world
#
#   julia> io = IOBuffer();
#
#   julia> println(io, "Hello, world")
#
#   julia> String(take!(io))
#   "Hello, world\n"

# %% [markdown]
# ## Strings

# %%
string1 = "Upilmu "
string2 = "cantik"
# Out:
# "cantik"

# %%
string(string1, string2)
string3 = string(string1, string2)
# Out:
# "Upilmu cantik"

# %%
string4 = "sangat "
# Out:
# "sangat "

# %%
println(string1, string4, string2)
# Out:
# Upilmu sangat cantik

# %%
m = 2
# Out:
# 2

# %%
println(string1, string4, string2,"$m")
# Out:
# Upilmu sangat cantik2

# %% [markdown]
# ## Data Structures

# %% [markdown]
# ### Tuples

# %%
myFavoriteColors = ("gray", "orange", "magenta", "blue")
# Out:
# ("gray", "orange", "magenta", "blue")

# %%
myFavoriteColors[1]
# Out:
# "gray"

# %%
for n in 1:4
    println(myFavoriteColors[n])
end
println()
for x in myFavoriteColors
    println(x)
end
# Out:
# gray
# orange
# magenta
# blue
#
# gray
# orange
# magenta
# blue

# %%
myFavoriteColors = ("gray", "orange", "magenta", "blue", 153, 1.2)
# Out:
# ("gray", "orange", "magenta", "blue", 153, 1.2)

# %% [markdown]
# ### Dictionaries
# https://en.wikibooks.org/wiki/Introducing_Julia/Dictionaries_and_sets

# %%
houseMates = Dict("Tim" => "Mathematics", "Jeremy" => "Biology", "Kevin" => "Comp Sci")
# Out:
# Dict{String,String} with 3 entries:
#   "Jeremy" => "Biology"
#   "Kevin"  => "Comp Sci"
#   "Tim"    => "Mathematics"

# %%
houseMates["Tim"]
# Out:
# "Mathematics"

# %%
houseMates["Rufus"]
# Out:
# KeyError: key "Rufus" not found
#
# Stacktrace:
#  [1] getindex(::Dict{String,String}, ::String) at ./dict.jl:478
#  [2] top-level scope at In[16]:1

# %%
houseMates["Mighty"] = "Comp Sci"
# Out:
# "Comp Sci"

# %%
# Can not have duplicate Kevins (1 is enough geez)
houseMates["Kevin"] = "Comp Science"
# Out:
# "Comp Science"

# %%
for x in houseMates
    println(x)
end
# Out:
# "Mighty" => "Comp Sci"
# "Jeremy" => "Biology"
# "Kevin" => "Comp Science"
# "Tim" => "Mathematics"

# %% [markdown]
# ### Arrays

# %%
coffee = ["Cold Brew", "Ice Coffee", "Latte", "Iced Cap"]
# Out:
# 4-element Array{String,1}:
#  "Cold Brew"
#  "Ice Coffee"
#  "Latte"
#  "Iced Cap"

# %%
fib = [1, 1, 2, 3, 5, 8, 13]
# Out:
# 7-element Array{Int64,1}:
#   1
#   1
#   2
#   3
#   5
#   8
#  13

# %%
whack = [1, "two", 3, "four", "five", 6, 7, 8]
# Out:
# 8-element Array{Any,1}:
#  1
#   "two"
#  3
#   "four"
#   "five"
#  6
#  7
#  8

# %%
#Creates a 4x3 array of random numbers
rand(4,3)
# Out:
# 4×3 Array{Float64,2}:
#  0.604401  0.068574  0.977623
#  0.723015  0.849441  0.313491
#  0.27872   0.122951  0.600716
#  0.60611   0.68157   0.653195

# %% [markdown]
# ## Loops

# %%
n = 0
while n < 4
    n += 1
    println(n)
end
# Out:
# 1
# 2
# 3
# 4

# %%
a = 5
println((a < 6) ? "hello" : "bye")
# Out:
# hello

# %% [markdown]
# ## Functions

# %%
function f(x)
    return x^2
end
f(4)
# Out:
# 16

# %%
f2(x) = x^2
f2(4)
# Out:
# 16

# %%
f3 = x -> x^2
# Out:
# #3 (generic function with 1 method)

# %%
f3(4)
# Out:
# 16

# %% [markdown]
# ### Duck Typing:
# Julia functions will work on whatever inputs make sense.

# %%
A = rand(3,3)
f(A)
# Out:
# 3×3 Array{Float64,2}:
#  0.855643  0.779976  0.434951
#  0.550084  0.736265  0.28481
#  0.624671  0.687736  0.377378

# %%
v = rand(3)
# Out:
# 3-element Array{Float64,1}:
#  0.06580316141367404
#  0.44541483497195244
#  0.0020194953681862415

# %%
# Not well defined--Do I mean dot product or cross product?
f(v)
# Out:
# MethodError: no method matching ^(::Array{Float64,1}, ::Int64)
# Closest candidates are:
#   ^(!Matched::Float16, ::Integer) at math.jl:782
#   ^(!Matched::Missing, ::Integer) at missing.jl:120
#   ^(!Matched::Missing, ::Number) at missing.jl:93
#   ...
#
# Stacktrace:
#  [1] macro expansion at ./none:0 [inlined]
#  [2] literal_pow at ./none:0 [inlined]
#  [3] f(::Array{Float64,1}) at ./In[26]:2
#  [4] top-level scope at In[32]:1

# %% [markdown]
# ### Mutating vs non-mutating functions
# By convention, functions followed by ! will alter contents and functions lacking ! do not.

# %%
v = [3, 5, 2]
sort(v)
v
# Out:
# 3-element Array{Int64,1}:
#  3
#  5
#  2

# %%
print(sort(v))
# Out:
# [2, 3, 5]

# %%
sort!(v)
v
# Out:
# 3-element Array{Int64,1}:
#  2
#  3
#  5

# %% [markdown]
# ## Linear Algebra

# %%
#range 1-10, 3x3 matrix
A = rand(1:10, 3, 3)
# Out:
# 3×3 Array{Int64,2}:
#  7  4  3
#  3  1  3
#  8  2  2

# %%
x = fill(1, (3))
# Out:
# 3-element Array{Int64,1}:
#  1
#  1
#  1

# %%
b = A*x
# Out:
# 3-element Array{Int64,1}:
#  14
#   7
#  12

# %%
A'
# Out:
# 3×3 LinearAlgebra.Adjoint{Int64,Array{Int64,2}}:
#  7  3  8
#  4  1  2
#  3  3  2

# %%
transpose(A)
# Out:
# 3×3 LinearAlgebra.Transpose{Int64,Array{Int64,2}}:
#  7  3  8
#  4  1  2
#  3  3  2

# %%
A'A
# Out:
# 3×3 Array{Int64,2}:
#  122  47  46
#   47  21  19
#   46  19  22

# %% [markdown]
# The following solves linear systems $Ax = b$ for __square__ $A$

# %%
A\b
# Out:
# 3-element Array{Float64,1}:
#  0.9999999999999999
#  1.0000000000000002
#  1.0

# %%
size(A)
# Out:
# (3, 3)

# %% [markdown]
# ## Packages

# %% [markdown]
# We can use Python or R in Julia via $PyCall$ and $Rcall$, so we also have several of those packages 'available' to us in Julia. To see available packages:
# https://pkg.julialang.org/ or https://juliaobserver.com/

# %%
using Pkg
Pkg.add("Example")
# Out:
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
# See https://github.com/JuliaLang/Example.jl/blob/master/src/Example.jl 
using Example

# %%
hello("Mighty")
domath(100)
# Out:
# 105

# %%
# https://github.com/JuliaGraphics/Colors.jl
# Docs at https://github.com/JuliaGraphics/Colors.jl/tree/e89197a32c9880f3be4a535d6880a0ac76dfa67c/docs/src
Pkg.add("Colors")
using Colors
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %%
pallete = distinguishable_colors(100)
# Out:
# 100-element Array{RGB{N0f8},1} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,0.384)
#  RGB{N0f8}(1.0,0.624,1.0)
#  RGB{N0f8}(0.0,0.839,1.0)
#  RGB{N0f8}(0.843,0.267,0.0)
#  RGB{N0f8}(0.0,0.502,0.161)
#  RGB{N0f8}(0.0,0.373,0.835)
#  RGB{N0f8}(0.576,0.0,0.408)
#  RGB{N0f8}(1.0,0.796,0.71)
#  RGB{N0f8}(0.655,0.525,0.0)
#  RGB{N0f8}(0.0,1.0,0.773)
#  RGB{N0f8}(0.0,0.494,0.525)
#  RGB{N0f8}(0.325,0.259,0.0)
#  ⋮
#  RGB{N0f8}(0.494,0.384,0.0)
#  RGB{N0f8}(0.094,0.365,0.365)
#  RGB{N0f8}(0.0,0.545,0.455)
#  RGB{N0f8}(1.0,0.247,0.216)
#  RGB{N0f8}(0.737,0.62,1.0)
#  RGB{N0f8}(0.51,0.455,0.427)
#  RGB{N0f8}(0.333,0.337,0.2)
#  RGB{N0f8}(0.329,0.741,1.0)
#  RGB{N0f8}(0.804,0.22,0.635)
#  RGB{N0f8}(0.506,0.827,0.675)
#  RGB{N0f8}(0.541,0.435,0.502)
#  RGB{N0f8}(0.969,0.714,0.416)

# %%
rand(3, 3)
# Out:
# 3×3 Array{Float64,2}:
#  0.0272211  0.0549511  0.95841
#  0.331764   0.570221   0.0230318
#  0.169131   0.642956   0.617373

# %%
rand(pallete, 3, 3)
# Out:
# 3×3 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(1.0,0.902,1.0)      …  RGB{N0f8}(0.459,0.345,1.0)
#  RGB{N0f8}(1.0,0.796,0.71)        RGB{N0f8}(0.333,0.337,0.2)
#  RGB{N0f8}(0.482,0.376,0.267)     RGB{N0f8}(0.18,0.196,0.282)

# %% [markdown]
# ## Plotting in Julia

# %%
Pkg.add("Plots")
using Plots
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1186

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17]
# Out:
# 6-element Array{Int64,1}:
#  45000
#  20000
#  15000
#   5000
#    400
#     17

# %%
# Need to run this before plotting
gr()
fntlg = Plots.font("sans-serif", 14.0)
# Out:
# Plots.Font("sans-serif", 14, :hcenter, :vcenter, 14.0, RGB{N0f8}(0.0,0.0,0.0))

# %%
plot(numpirates, globaltemperatures, label="line")
scatter!(numpirates, globaltemperatures, label="points")

# %% [markdown]
#  We use ! for scatter! because we want the scattered points to be on the pre-existing plot.

# %%
plot(numpirates, globaltemperatures, label="line")
scatter(numpirates, globaltemperatures, label="points")

# %%
plot(numpirates, globaltemperatures, label="line")
scatter!(numpirates, globaltemperatures, label="points")
xlabel!("Number of Pirates")
ylabel!("Global Temperature (C)")
title!("Influence of Pirate Population on Global Warming")

# %%
xflip!()

# %% [markdown]
# ## Comparing Speeds of Julia to other Languages

# %%
a = rand(10^7)
# Out:
# 10000000-element Array{Float64,1}:
#  0.38139369329347783
#  0.18646931125891086
#  0.5526066353430077
#  0.7462335900744168
#  0.6580844041033687
#  0.696096846403842
#  0.32562563913301523
#  0.774735552707847
#  0.311231915010483
#  0.3543694275082392
#  0.0923930432746971
#  0.673882320658963
#  0.19796029655052472
#  ⋮
#  0.13762973425824576
#  0.20347524618798207
#  0.08577929563212017
#  0.5100007385317433
#  0.2812496142606846
#  0.13620279020478043
#  0.8457279553962618
#  0.5257679252463878
#  0.08212559031921907
#  0.9152026449575854
#  0.4158257780180321
#  0.15078719620207282

# %%
sum(a)
# Out:
# 5.002393330884922e6

# %%
@time sum(a)
# Out:
#   0.004746 seconds (5 allocations: 176 bytes)
# 5.002393330884922e6

# %%
@time sum(a)
# Out:
#   0.004738 seconds (5 allocations: 176 bytes)
# 5.002393330884922e6

# %% [markdown]
# We can use this package to Benchmark better.

# %%
Pkg.add("BenchmarkTools")
using BenchmarkTools
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]

# %% [markdown]
# __source: https://github.com/JuliaComputing/JuliaBoxTutorials/blob/master/introductory-tutorials/intro-to-julia/short-version/05.Julia_is_fast.ipynb __
#
#
# C is often considered the gold standard: difficult on the human, nice for the machine. Getting within a factor of 2 of C is often satisfying. Nonetheless, even within C, there are many kinds of optimizations possible that a naive C writer may or may not get the advantage of.
#
# The current author does not speak C, so he does not read the cell below, but is happy to know that you can put C code in a Julia session, compile it, and run it. Note that the """ wrap a multi-line string.

# %%
using Libdl
C_code = """
#include <stddef.h>
double c_sum(size_t n, double *X) {
    double s = 0.0;
    for (size_t i = 0; i < n; ++i) {
        s += X[i];
    }
    return s;
}
"""

const Clib = tempname()   # make a temporary file


# compile to a shared library by piping C_code to gcc
# (works only if you have gcc installed):

open(`gcc -fPIC -O3 -msse3 -xc -shared -o $(Clib * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# define a Julia function that calls the C function:
c_sum(X::Array{Float64}) = ccall(("c_sum", Clib), Float64, (Csize_t, Ptr{Float64}), length(X), X)
# Out:
# c_sum (generic function with 1 method)

# %%
c_sum(a)
# Out:
# 5.002393330884926e6

# %%
@time c_sum(a)
# Out:
#   0.011363 seconds (5 allocations: 176 bytes)
# 5.002393330884926e6

# %%
c_sum(a) ≈ sum(a)
# Out:
# true

# %%
c_sum(a) - sum(a)
# Out:
# 3.725290298461914e-9

# %%
c_bench = @benchmark c_sum($a)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  0 bytes
#   allocs estimate:  0
#   --------------
#   minimum time:     10.252 ms (0.00% GC)
#   median time:      10.649 ms (0.00% GC)
#   mean time:        10.689 ms (0.00% GC)
#   maximum time:     12.772 ms (0.00% GC)
#   --------------
#   samples:          468
#   evals/sample:     1

# %%
println("C: Fastest time was $(minimum(c_bench.times) / 1e6) msec")
# Out:
# C: Fastest time was 10.251714 msec

# %%
d = Dict()  # a "dictionary", i.e. an associative array
d["C"] = minimum(c_bench.times) / 1e6  # in milliseconds
d
# Out:
# Dict{Any,Any} with 1 entry:
#   "C" => 10.2517

# %%
using Statistics # bring in statistical support for standard deviations
t = c_bench.times / 1e6 # times in milliseconds
m, σ = minimum(t), std(t)

histogram(t, bins=500,
    xlim=(m - 0.01, m + σ),
    xlabel="milliseconds", ylabel="count", label="")

# %%
# C with --ffast-math
const Clib_fastmath = tempname()   # make a temporary file

# The same as above but with a -ffast-math flag added
open(`gcc -fPIC -O3 -msse3 -xc -shared -ffast-math -o $(Clib_fastmath * "." * Libdl.dlext) -`, "w") do f
    print(f, C_code) 
end

# define a Julia function that calls the C function:
c_sum_fastmath(X::Array{Float64}) = ccall(("c_sum", Clib_fastmath), Float64, (Csize_t, Ptr{Float64}), length(X), X)

c_fastmath_bench = @benchmark $c_sum_fastmath($a)
d["C -ffast-math"] = minimum(c_fastmath_bench.times) / 1e6  # in milliseconds
# Out:
# 5.261289

# %%
Pkg.add("PyCall")
using PyCall
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
# ┌ Info: Precompiling PyCall [438e738f-606a-5dbb-bf0a-cddfbfd45ab0]
# └ @ Base loading.jl:1186

# %%
pysum = pybuiltin("sum")
pysum(a)
py_list_bench = @benchmark $pysum($a)
d["Python built-in"] = minimum(py_list_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 3 entries:
#   "C"               => 10.2517
#   "Python built-in" => 592.42
#   "C -ffast-math"   => 5.26129

# %%
Pkg.add("Conda")
using Conda
numpy_sum = pyimport("numpy")["sum"]
py_numpy_bench = @benchmark $numpy_sum($a)
d["Python numpy"] = minimum(py_numpy_bench.times) / 1e6
d
# Out:
#  Resolving package versions...
#   Updating `~/.julia/environments/v1.0/Project.toml`
#  [no changes]
#   Updating `~/.julia/environments/v1.0/Manifest.toml`
#  [no changes]
# Dict{Any,Any} with 4 entries:
#   "C"               => 10.2517
#   "Python numpy"    => 3.59229
#   "Python built-in" => 592.42
#   "C -ffast-math"   => 5.26129

# %%
py"""
def py_sum(A):
    s = 0.0
    for a in A:
        s += a
    return s
"""

sum_py = py"py_sum"
py_hand = @benchmark $sum_py($a)
d["Python hand-written"] = minimum(py_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 5 entries:
#   "C"                   => 10.2517
#   "Python numpy"        => 3.59229
#   "Python hand-written" => 703.926
#   "Python built-in"     => 592.42
#   "C -ffast-math"       => 5.26129

# %%
j_bench = @benchmark sum($a)
d["Julia built-in"] = minimum(j_bench.times) / 1e6
d
# Out:
# Dict{Any,Any} with 6 entries:
#   "C"                   => 10.2517
#   "Python numpy"        => 3.59229
#   "Python hand-written" => 703.926
#   "Python built-in"     => 592.42
#   "Julia built-in"      => 3.31588
#   "C -ffast-math"       => 5.26129

# %%
function mysum(A)   
    s = 0.0 # s = zero(eltype(a))
    for a in A
        s += a
    end
    s
end
j_bench_hand = @benchmark mysum($a)
d["Julia hand-written"] = minimum(j_bench_hand.times) / 1e6
d
# Out:
# Dict{Any,Any} with 7 entries:
#   "C"                   => 10.2517
#   "Python numpy"        => 3.59229
#   "Julia hand-written"  => 10.2576
#   "Python hand-written" => 703.926
#   "Python built-in"     => 592.42
#   "Julia built-in"      => 3.31588
#   "C -ffast-math"       => 5.26129

# %%
function mysum_simd(A)   
    s = 0.0 # s = zero(eltype(A))
    @simd for a in A
        s += a
    end
    s
end
j_bench_hand_simd = @benchmark mysum_simd($a)
mysum_simd(a)
d["Julia hand-written simd"] = minimum(j_bench_hand_simd.times) / 1e6
d
# Out:
# Dict{Any,Any} with 8 entries:
#   "Julia hand-written simd" => 3.35973
#   "C"                       => 10.2517
#   "Python numpy"            => 3.59229
#   "Julia hand-written"      => 10.2576
#   "Python hand-written"     => 703.926
#   "Python built-in"         => 592.42
#   "Julia built-in"          => 3.31588
#   "C -ffast-math"           => 5.26129

# %%
for (key, value) in sort(collect(d), by=last)
    println(rpad(key, 25, "."), lpad(round(value; digits=1), 6, "."))
end
# Out:
# Julia built-in..............3.3
# Julia hand-written simd.....3.4
# Python numpy................3.6
# C -ffast-math...............5.3
# C..........................10.3
# Julia hand-written.........10.3
# Python built-in...........592.4
# Python hand-written.......703.9
